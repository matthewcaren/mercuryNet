# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter

# %% [markdown]
# ## Load Data

# %%
DATA_FILE = '../data/avspeech_test_langs.csv'

# %%
data = pd.read_csv(DATA_FILE)
data
# Out:
#         Unnamed: 0           ID           s           e         x         y  \
# 0                0  u5MPyrRJPmc  108.240000  111.240000  0.849219  0.305556
# 1                1  H1ulMfj5wRY  112.320000  116.940000  0.112500  0.345833
# 2                2  -wuxbgMRIWs   30.030000   36.745044  0.744531  0.211111
# 3                3  GNRPRH-E-sI   30.230200   38.171467  0.333594  0.494444
# 4                4  VvcwAGkSy2o  240.200000  253.366667  0.491667  0.372222
# ...            ...          ...         ...         ...       ...       ...
# 183268      183268  80pU4f5HFmg  211.000000  219.280000  0.488542  0.296296
# 183269      183269  FJ3gPk5Cv-g  294.330367  297.330367  0.598958  0.361111
# 183270      183270  LX6_rQjQDZA  234.200633  239.973067  0.110156  0.136111
# 183271      183271  79RVP6WqHR4  240.006433  243.042800  0.283854  0.230556
# 183272      183272  LsmFkm22UT0  135.880000  145.000000  0.214062  0.273148
#
#        Language
# 0            fr
# 1            nl
# 2            vi
# 3            en
# 4            tr
# ...         ...
# 183268       en
# 183269       pl
# 183270       en
# 183271       tr
# 183272       en
#
# [183273 rows x 7 columns]

# %% [markdown]
# ## Plotting Helpers

# %%
def plot_pie(data_list, title=None):
    counts = Counter(data_list)
    labels, counts = zip(*counts.items())
    plt.pie(counts, labels=labels)
    plt.title(title)

# %% [markdown]
# ## Data Analysis

# %%
plot_pie(data['Language'], title="Language Distribution")
